# %%
import pandas as pd
df = pd.read_csv('http.csv')
df.head()
# Out:
#          f1        f2         f3  attack
# 0 -2.302585  5.371103  10.716107       0
# 1 -2.302585  5.088213   8.418058       0
# 2 -2.302585  5.464255   7.113224       0
# 3 -2.302585  5.451468   7.616825       0
# 4 -2.302585  5.476882   6.186414       0

# %%
del df['f1']
del df['attack']

# %%
df = df.dropna()

# %%
df
# Out:
#               f2         f3
# 0       5.371103  10.716107
# 1       5.088213   8.418058
# 2       5.464255   7.113224
# 3       5.451468   7.616825
# 4       5.476882   6.186414
# ...          ...        ...
# 567493  5.357058   7.735477
# 567494  5.389528   5.464255
# 567495  5.384954   8.191491
# 567496  5.389528   7.118097
# 567497  5.389528   7.001337
#
# [567498 rows x 2 columns]

# %%
df = df.drop(df.index[100000:567498])

# %%
df
# Out:
#              f2         f3
# 0      5.371103  10.716107
# 1      5.088213   8.418058
# 2      5.464255   7.113224
# 3      5.451468   7.616825
# 4      5.476882   6.186414
# ...         ...        ...
# 99995  5.308763   7.268990
# 99996  5.273512   7.735477
# 99997  5.268373   9.872776
# 99998  5.371103   9.297169
# 99999  5.308763   7.001337
#
# [100000 rows x 2 columns]

# %%
df.head()
# Out:
#          f2         f3
# 0  5.371103  10.716107
# 1  5.088213   8.418058
# 2  5.464255   7.113224
# 3  5.451468   7.616825
# 4  5.476882   6.186414

# %%
import matplotlib.pyplot as plt
plt.scatter(df.iloc[:,0], df.iloc[:,1])

# %%
from sklearn.ensemble import IsolationForest

# %%
clf = IsolationForest(contamination = auto)
clf.fit(df)

# Make predictions
predictions = clf.predict(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-103-f7a5f969f059> in <cell line: 1>()
# ----> 1 clf = IsolationForest(contamination = auto)
#       2 clf.fit(df)
#       3
#       4 # Make predictions
#       5 predictions = clf.predict(df)
#
# NameError: name 'auto' is not defined

# %%
predictions
# Out:
# array([-1, -1,  1, ..., -1,  1,  1])

# %%
import numpy as np
index = np.where(predictions < 0)
index
# Out:
# (array([    0,     1,    10, ..., 99928, 99979, 99997]),)

# %%
x = df.values

# %%
index = np.where(predictions < 0)
plt.scatter(df.iloc[:,0], df.iloc[:,1])
plt.scatter(x[index,0], x[index,1], edgecolors = 'r')
